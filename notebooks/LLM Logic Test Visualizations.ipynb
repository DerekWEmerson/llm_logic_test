# %% [markdown]
# # LLM Logic Test Visualizations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\leost\Downloads\AnalystBuilder\LLM Logic Analysis\LLM Logic Test Observations.xlsx", index_col = 'Index')

# %%
df
# Out:
#                                         Category                 Prompt  \
# Index
# 1                                 Game Mechanics                    UNO
# 2                                 Game Mechanics                    UNO
# 3                                 Game Mechanics                    UNO
# 4                                 Game Mechanics                  Durak
# 5                                 Game Mechanics                  Durak
# 6                                 Game Mechanics                  Durak
# 7                                 Game Mechanics      I'm Going Camping
# 8                                 Game Mechanics      I'm Going Camping
# 9                                 Game Mechanics      I'm Going Camping
# 10                 Social Fairness & Turn-Taking           Cookie Party
# 11                 Social Fairness & Turn-Taking           Cookie Party
# 12                 Social Fairness & Turn-Taking           Cookie Party
# 13                 Social Fairness & Turn-Taking             Turn Order
# 14                 Social Fairness & Turn-Taking             Turn Order
# 15                 Social Fairness & Turn-Taking             Turn Order
# 16                 Social Fairness & Turn-Taking             Basketball
# 17                 Social Fairness & Turn-Taking             Basketball
# 18                 Social Fairness & Turn-Taking             Basketball
# 19               Procedural Tasks & Cause-Effect                Curling
# 20               Procedural Tasks & Cause-Effect                Curling
# 21               Procedural Tasks & Cause-Effect                Curling
# 22               Procedural Tasks & Cause-Effect                Musical
# 23               Procedural Tasks & Cause-Effect                Musical
# 24               Procedural Tasks & Cause-Effect                Musical
# 25               Procedural Tasks & Cause-Effect      Server Moderation
# 26               Procedural Tasks & Cause-Effect      Server Moderation
# 27               Procedural Tasks & Cause-Effect      Server Moderation
# 28     Fictional World Rules (Constructed Logic)          Magic Bananas
# 29     Fictional World Rules (Constructed Logic)          Magic Bananas
# 30     Fictional World Rules (Constructed Logic)          Magic Bananas
# 31     Fictional World Rules (Constructed Logic)     Spell Construction
# 32     Fictional World Rules (Constructed Logic)     Spell Construction
# 33     Fictional World Rules (Constructed Logic)     Spell Construction
# 34     Fictional World Rules (Constructed Logic)        Ouroborian Mark
# 35     Fictional World Rules (Constructed Logic)        Ouroborian Mark
# 36     Fictional World Rules (Constructed Logic)        Ouroborian Mark
# 37                   Pattern & Deduction Puzzles            Card Cypher
# 38                   Pattern & Deduction Puzzles            Card Cypher
# 39                   Pattern & Deduction Puzzles            Card Cypher
# 40                   Pattern & Deduction Puzzles          Rainbow Order
# 41                   Pattern & Deduction Puzzles          Rainbow Order
# 42                   Pattern & Deduction Puzzles          Rainbow Order
# 43                   Pattern & Deduction Puzzles  Behavioral Reflection
# 44                   Pattern & Deduction Puzzles  Behavioral Reflection
# 45                   Pattern & Deduction Puzzles  Behavioral Reflection
#
#                Expected Answer              Model  \
# Index
# 1                           No         ChatGPT 4o
# 2                           No  Claude 3.7 Sonnet
# 3                           No       DeepThink R1
# 4                          Yes         ChatGPT 4o
# 5                          Yes  Claude 3.7 Sonnet
# 6                          Yes       DeepThink R1
# 7                          Yes         ChatGPT 4o
# 8                          Yes  Claude 3.7 Sonnet
# 9                          Yes       DeepThink R1
# 10                         Yes         ChatGPT 4o
# 11                         Yes  Claude 3.7 Sonnet
# 12                         Yes       DeepThink R1
# 13              Order Restored         ChatGPT 4o
# 14              Order Restored  Claude 3.7 Sonnet
# 15              Order Restored       DeepThink R1
# 16          Devon (Alt. Chris)         ChatGPT 4o
# 17          Devon (Alt. Chris)  Claude 3.7 Sonnet
# 18          Devon (Alt. Chris)       DeepThink R1
# 19        Lose Balance or Fall         ChatGPT 4o
# 20        Lose Balance or Fall  Claude 3.7 Sonnet
# 21        Lose Balance or Fall       DeepThink R1
# 22            Throw Off Timing         ChatGPT 4o
# 23            Throw Off Timing  Claude 3.7 Sonnet
# 24            Throw Off Timing       DeepThink R1
# 25        Make Unfair Decision         ChatGPT 4o
# 26        Make Unfair Decision  Claude 3.7 Sonnet
# 27        Make Unfair Decision       DeepThink R1
# 28                         100         ChatGPT 4o
# 29                         100  Claude 3.7 Sonnet
# 30                         100       DeepThink R1
# 31                  Immobility         ChatGPT 4o
# 32                  Immobility  Claude 3.7 Sonnet
# 33                  Immobility       DeepThink R1
# 34            Nyla Disappeared         ChatGPT 4o
# 35            Nyla Disappeared  Claude 3.7 Sonnet
# 36            Nyla Disappeared       DeepThink R1
# 37                           T         ChatGPT 4o
# 38                           T  Claude 3.7 Sonnet
# 39                           T       DeepThink R1
# 40                      Yellow         ChatGPT 4o
# 41                      Yellow  Claude 3.7 Sonnet
# 42                      Yellow       DeepThink R1
# 43     Storytelling Profession         ChatGPT 4o
# 44     Storytelling Profession  Claude 3.7 Sonnet
# 45     Storytelling Profession       DeepThink R1
#
#                                           Model Response Correct? (Y/N)  \
# Index
# 1      No, Player C’s move was not legal.\n\nLet's br...              Y
# 2      Player C's move was not legal in UNO.\nAccordi...              Y
# 3      Player C's move was not legal.\n\nHere's the b...              Y
# 4      In Durak, a card is only legal to play if it m...              N
# 5      No, the 7♠ does not become legal retroactively...              N
# 6      In Durak, the legality of a card played is det...              N
# 7      Let's look for a hidden pattern in the items p...              Y
# 8      Let me think through this step by step.\nFor t...              P
# 9      The key to determining whether Gina can bring ...              P
# 10     Yes, this can be considered fair.\n\nFairness ...              Y
# 11     This is a thoughtful question about fairness t...              Y
# 12     The situation can be viewed through the lens o...              Y
# 13     Jules is right — it isn't fair.\n\nIn a board ...              Y
# 14     According to the rules you've described, the o...              Y
# 15     The correct turn order should follow the origi...              Y
# 16     The best choice is Chris.\n\nHere’s why:\n\nCh...              P
# 17     This is an interesting decision with several f...              Y
# 18     The decision should be based on merit and team...              P
# 19     If a curling player steps onto the teflon slid...              Y
# 20     If a player steps onto their teflon slider bef...              Y
# 21     If a curler steps onto the Teflon slider befor...              Y
# 22     If a student forgets to sing the second verse ...              Y
# 23     The student forgetting to sing the second vers...              Y
# 24     When a student forgets to sing the second vers...              Y
# 25     If the moderator skips Step 2: Listening to bo...              Y
# 26     If the moderator skips Step 2 (listening to bo...              Y
# 27     If the moderator skips Step 2 (listening to bo...              Y
# 28     In the Jungle of Luthrain, there are always ex...              Y
# 29     This question requires careful attention to th...              Y
# 30     In the Jungle of Luthrain, the total number of...              Y
# 31     In the magical language of Arcant, where spell...              Y
# 32     In the magical world of Fabul, a "Foot Freeze"...              Y
# 33     The combination of "Foot" + "Freeze" in Arcant...              Y
# 34     The tale of the Ouroborians is steeped in symb...              Y
# 35     This is a fascinating magical scenario with cl...              Y
# 36     The disappearance of Nyla can be attributed to...              Y
# 37     To decode the '7 of Clubs' using the secret co...              Y
# 38     To solve this code, I'll work through it step ...              Y
# 39     The '7 of Clubs' in the spy code corresponds t...              Y
# 40     The correct order of the rainbow colors is:\n\...              Y
# 41     To solve this problem, I need to recall the co...              Y
# 42     The correct order of the rainbow as specified ...              Y
# 43     If a child constantly made up stories, that im...              Y
# 44     Based on the pattern you've described, someone...              Y
# 45     Based on the observed pattern where childhood ...              Y
#
#                                         Reason for Score  \
# Index
# 1              Correctly answered with sound reasoning.
# 2              Correctly answered with sound reasoning.
# 3              Correctly answered with sound reasoning.
# 4      Noted the informal legal-cheating rules, but s...
# 5                   Did not acknowledge any house rules.
# 6      Mentioned house rules but only for penalizatio...
# 7      Correctly answered with correct reasoning, how...
# 8      Claude was partially correct, having answered ...
# 9      DeepSeek was partially correct, having answere...
# 10     Correctly answered with sound reasoning. Respo...
# 11     Correctly answered with sound reasoning. Was m...
# 12     Correctly answered with sound reasoning. Discu...
# 13     Correctly answered with sound reasoning with a...
# 14     This was harder to justify, but the model did ...
# 15     Correctly answered with sound reasoning. Gave ...
# 16     Answered the question by taking the performanc...
# 17     Answered the question thoughtfully, taking the...
# 18     Answered the question with merit and competiti...
# 19     Correctly answered with sound reasoning. Liste...
# 20     Correctly answered with sound reasoning. Liste...
# 21     Correctly answered with sound reasoning. Liste...
# 22     Answered correctly, giving several potential o...
# 23     Answered correctly, giving several potential o...
# 24     Answered correctly, giving several potential o...
# 25     Correctly answered with thurough and sound rea...
# 26     Correctly answered with thurough and sound rea...
# 27     Correctly answered with thurough and sound rea...
# 28             Correctly answered with sound reasoning.
# 29             Correctly answered with sound reasoning.
# 30             Correctly answered with sound reasoning.
# 31     Listed multiple potential spell effects that e...
# 32     Listed multiple potential spell effects that e...
# 33     Listed multiple potential spell effects that e...
# 34     Gave the correct answer, but wasn't very direc...
# 35     Gave the correct answer (draining life force),...
# 36     Correctly answered the prompt ("erased from ex...
# 37             Correctly answered with sound reasoning.
# 38             Correctly answered with sound reasoning.
# 39             Correctly answered with sound reasoning.
# 40             Correctly answered with sound reasoning.
# 41             Correctly answered with sound reasoning.
# 42             Correctly answered with sound reasoning.
# 43     Correctly listed numerous career fields that c...
# 44     Correctly listed numerous career fields that c...
# 45     Gave less answers, but looking at its thought ...
#
#                           Comparative Notes/Observations
# Index
# 1      All three referenced the correct rule, listed ...
# 2      All three referenced the correct rule, listed ...
# 3      All three referenced the correct rule, listed ...
# 4      Each model correctly defined the ruling accord...
# 5      Each model correctly defined the ruling accord...
# 6      Each model correctly defined the ruling accord...
# 7      Claude responded the quickest but was incorrec...
# 8      Claude responded the quickest but was incorrec...
# 9      Claude responded the quickest but was incorrec...
# 10     All three models answered correctly, with Chat...
# 11     All three models answered correctly, with Chat...
# 12     All three models answered correctly, with Chat...
# 13     All three models framed their responses in reg...
# 14     All three models framed their responses in reg...
# 15     All three models framed their responses in reg...
# 16     ChatGPT and DeepSeek took the stance of merit ...
# 17     ChatGPT and DeepSeek took the stance of merit ...
# 18     ChatGPT and DeepSeek took the stance of merit ...
# 19     All models answered correctly, each explaining...
# 20     All models answered correctly, each explaining...
# 21     All models answered correctly, each explaining...
# 22     All three models answered correctly, each list...
# 23     All three models answered correctly, each list...
# 24     All three models answered correctly, each list...
# 25     Each model gave numerous logical outcomes for ...
# 26     Each model gave numerous logical outcomes for ...
# 27     Each model gave numerous logical outcomes for ...
# 28     All three answered correctly with sound reason...
# 29     All three answered correctly with sound reason...
# 30     All three answered correctly with sound reason...
# 31     In a prompt that can have multiple subjective ...
# 32     In a prompt that can have multiple subjective ...
# 33     In a prompt that can have multiple subjective ...
# 34     Each prompt gave the correct answer with sound...
# 35     Each prompt gave the correct answer with sound...
# 36     Each prompt gave the correct answer with sound...
# 37     All three answered correctly with sound reason...
# 38     All three answered correctly with sound reason...
# 39     All three answered correctly with sound reason...
# 40     All three answered correctly with sound reason...
# 41     All three answered correctly with sound reason...
# 42     All three answered correctly with sound reason...
# 43     All three answered correctly with sound reason...
# 44     All three answered correctly with sound reason...
# 45     All three answered correctly with sound reason...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 1 to 45
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Category                        45 non-null     object
#  1   Prompt                          45 non-null     object
#  2   Expected Answer                 45 non-null     object
#  3   Model                           45 non-null     object
#  4   Model Response                  45 non-null     object
#  5   Correct? (Y/N)                  45 non-null     object
#  6   Reason for Score                45 non-null     object
#  7   Comparative Notes/Observations  45 non-null     object
# dtypes: object(8)
# memory usage: 3.2+ KB

# %%
pivot_df = df.groupby(['Model', 'Correct? (Y/N)']).size().unstack(fill_value=0)
pivot_df
# Out:
# Correct? (Y/N)     N  P   Y
# Model
# ChatGPT 4o         1  1  13
# Claude 3.7 Sonnet  1  1  13
# DeepThink R1       1  2  12

# %%
pivot_df = pivot_df[['Y', 'P', 'N']]

# %%
pivot_df.sort_values(by='Model', ascending = False).plot(kind='barh', stacked=True, figsize=(10, 6), color = ['#4CAF50', '#FFA726', '#EF5350'])

plt.title('Model Performance')
plt.xlabel('Number of Prompts')
plt.ylabel('Model')
plt.yticks(rotation=90)
plt.tight_layout()

# %%
df.groupby(['Category', 'Model', 'Correct? (Y/N)']).size().unstack(fill_value=0)
# Out:
# Correct? (Y/N)                                               N  P  Y
# Category                                  Model
# Fictional World Rules (Constructed Logic) ChatGPT 4o         0  0  3
#                                           Claude 3.7 Sonnet  0  0  3
#                                           DeepThink R1       0  0  3
# Game Mechanics                            ChatGPT 4o         1  0  2
#                                           Claude 3.7 Sonnet  1  1  1
#                                           DeepThink R1       1  1  1
# Pattern & Deduction Puzzles               ChatGPT 4o         0  0  3
#                                           Claude 3.7 Sonnet  0  0  3
#                                           DeepThink R1       0  0  3
# Procedural Tasks & Cause-Effect           ChatGPT 4o         0  0  3
#                                           Claude 3.7 Sonnet  0  0  3
#                                           DeepThink R1       0  0  3
# Social Fairness & Turn-Taking             ChatGPT 4o         0  1  2
#                                           Claude 3.7 Sonnet  0  0  3
#                                           DeepThink R1       0  1  2

# %%
category_scores = df.groupby(['Category', 'Correct? (Y/N)']).size().unstack(fill_value=0)
category_scores
# Out:
# Correct? (Y/N)                             N  P  Y
# Category
# Fictional World Rules (Constructed Logic)  0  0  9
# Game Mechanics                             3  2  4
# Pattern & Deduction Puzzles                0  0  9
# Procedural Tasks & Cause-Effect            0  0  9
# Social Fairness & Turn-Taking              0  2  7

# %%
category_scores[['Y', 'P', 'N']].plot(kind='bar', stacked=True, figsize=(10, 6), color = ['#4CAF50', '#FFA726', '#EF5350'])

plt.title('Cumulative Accuracy by Category')
plt.xlabel('Category')
plt.ylabel('Number of Prompts')
plt.xticks(rotation=0, ha='center', fontsize=8)
plt.tight_layout()

# %%
heatmap_data = df[df['Correct? (Y/N)'] == 'Y'].groupby(['Category', 'Model']).size().unstack(fill_value=0)
heatmap_data
# Out:
# Model                                      ChatGPT 4o  Claude 3.7 Sonnet  \
# Category
# Fictional World Rules (Constructed Logic)           3                  3
# Game Mechanics                                      2                  1
# Pattern & Deduction Puzzles                         3                  3
# Procedural Tasks & Cause-Effect                     3                  3
# Social Fairness & Turn-Taking                       2                  3
#
# Model                                      DeepThink R1
# Category
# Fictional World Rules (Constructed Logic)             3
# Game Mechanics                                        1
# Pattern & Deduction Puzzles                           3
# Procedural Tasks & Cause-Effect                       3
# Social Fairness & Turn-Taking                         2

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', cbar=True)
plt.title('Correct Answers by Model and Category')
plt.xlabel('Model')
plt.ylabel('Logic Category')
plt.tight_layout()

# %%
# Exporting Plots to PNGs.

# %%
pivot_df.sort_values(by='Model', ascending = False).plot(kind='barh', stacked=True, figsize=(10, 6), color = ['#4CAF50', '#FFA726', '#EF5350'])

plt.title('Model Performance')
plt.xlabel('Number of Prompts')
plt.ylabel('Model')
plt.yticks(rotation=90)
plt.tight_layout()
plt.savefig('model_performance.png', dpi=300, bbox_inches='tight')

# %%
category_scores[['Y', 'P', 'N']].plot(kind='bar', stacked=True, figsize=(10, 6), color = ['#4CAF50', '#FFA726', '#EF5350'])

plt.title('Cumulative Accuracy by Category')
plt.xlabel('Category')
plt.ylabel('Number of Prompts')
plt.xticks(rotation=0, ha='center', fontsize=8)
plt.tight_layout()
plt.savefig('category_accuracy.png', dpi=300, bbox_inches='tight')

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', cbar=True)
plt.title('Correct Answers by Model and Category')
plt.xlabel('Model')
plt.ylabel('Logic Category')
plt.tight_layout()
plt.savefig('model_and_category.png', dpi=300, bbox_inches='tight')
